# %% [markdown]
# THIS SOLUTION IS INCOMPLETE (works but much too slow)
# ==========
#
# <img src="https://projecteuler.net/themes/default/pe_logo_default.png" alt="Project Euler" align="left">
# <br>
#
# # [Problem 12 - Highly divisible triangular number.](https://projecteuler.net/problem=12)
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be $1 + 2 + 3 + 4 + 5 + 6 + 7 = 28$. The first ten terms would be:
#
# $1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...$
#
# Let us list the factors of the first seven triangle numbers:
#
#      1: 1
#      3: 1,3
#      6: 1,2,3,6
#     10: 1,2,5,10
#     15: 1,3,5,15
#     21: 1,3,7,21
#     28: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %% [markdown]
# First we need to generate triangle numbers
# ---
#
# We'll write a generator that works just like range(), but returns triangle numbers.
#
# Note how we use "*args" here - it allows us to allow the function to take a TBD number of inputs, which we then pass on to the range() generator we use inside the function.

# %%
def triangle(*args):
    for n in range(*args):
        yield n*(n+1)/2

# %%
# Let's test our generator by generating the first 7 triangle numbers
triangle(7)

# %% [markdown]
# Aha, maybe you were expecting to get back triangle numbers, but that's not what we got.
#
# Can you tell
# 1. What did we get here?
# 2. How do we test our generator?

# %%
# Let's use a list comprehension
[n for n in triangle(7)]

# %%
# Not quite right, try again
[n for n in triangle(1,8)]

# %%
def number_of_divisors(x):
    divisors = 2  # Count 1 and X as divisors automatically
    for i in range(2,x):
        if (x % i) == 0:
            divisors += 1
    return divisors

# %%
target = 50
found = False
for i in triangle(1,5000):
    d = number_of_divisors(i)
    if (d > target):
        print "Solution found with triangle number", i, "which has", d, "divisors"
        found = True
        break
        
if not found:
    print "Searched up to", i, "but solution not found"

# %% [markdown]
# This method will product the correct answer, but it gets increasingly slow for larger triangle numbers, and using this approach took several hours to find the correct answer on my laptop.
#
# Can you come up with a better algorithm to solve this problem more quickly?
